# %% [markdown]
# After we've done the scraping phase, we will dive to the cleaning phase

# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("/Users/ahmed/Documents/ESILV/s9/web scraping/ecostay/ecostay/sustainable_hotels_paris3.csv")

# %%
df_1.head()
# Out:
#                               Name          Address  \
# 0           NH Paris Gare de l'Est  10e arr., Paris
# 1       Citadines Austerlitz Paris  13e arr., Paris
# 2  B&B HOTEL Paris Porte des Lilas  19e arr., Paris
# 3  Best Western Hotel Opéra Drouot   9e arr., Paris
# 4                 Hotel de la Tour  14e arr., Paris
#
#                                          Description                Rating  \
# 0  10e arr., ParisIndiquer sur la carte2,2 km du ...  Avec une note de 8,1
# 1  13e arr., ParisIndiquer sur la carte2,5 km du ...  Avec une note de 8,2
# 2  19e arr., ParisIndiquer sur la carte4,9 km du ...  Avec une note de 7,8
# 3  9e arr., ParisIndiquer sur la carte1,9 km du c...  Avec une note de 8,0
# 4  14e arr., ParisIndiquer sur la carte2,7 km du ...  Avec une note de 8,2
#
#   RatingText                 NumReviews  \
# 0  Très bien   1 398 expériences vécues
# 1  Très bien   1 971 expériences vécues
# 2       Bien  14 516 expériences vécues
# 3  Très bien   1 677 expériences vécues
# 4  Très bien     736 expériences vécues
#
#                                            HotelLink
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...

# %% [markdown]
# for the address and description we have collected them in another way (better way since here are so general or not full) in the other csvs, so we need to drop those

# %%
df_1.drop(columns=["Address","Description","NumReviews"],inplace=True)

# %%
df_1.head()
# Out:
#                               Name                Rating RatingText  \
# 0           NH Paris Gare de l'Est  Avec une note de 8,1  Très bien
# 1       Citadines Austerlitz Paris  Avec une note de 8,2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas  Avec une note de 7,8       Bien
# 3  Best Western Hotel Opéra Drouot  Avec une note de 8,0  Très bien
# 4                 Hotel de la Tour  Avec une note de 8,2  Très bien
#
#                                            HotelLink
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...

# %% [markdown]
# As we can see the rating is not float and there is some text before values, let's fix this :

# %%
df_1['Rating'] = df_1['Rating'].str.extract(r'(\d+,\d+)')

# %%
df_1.head()
# Out:
#                               Name Rating RatingText  \
# 0           NH Paris Gare de l'Est    8,1  Très bien
# 1       Citadines Austerlitz Paris    8,2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas    7,8       Bien
# 3  Best Western Hotel Opéra Drouot    8,0  Très bien
# 4                 Hotel de la Tour    8,2  Très bien
#
#                                            HotelLink
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...

# %%
df_1['Rating'] = df_1['Rating'].str.replace(',', '.').astype(float)

# %%
df_1.isnull().sum()
# Out:
# Name          0
# Rating        0
# RatingText    0
# HotelLink     0
# dtype: int64

# %%
df_1.head()
# Out:
#                               Name  Rating RatingText  \
# 0           NH Paris Gare de l'Est     8.1  Très bien
# 1       Citadines Austerlitz Paris     8.2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas     7.8       Bien
# 3  Best Western Hotel Opéra Drouot     8.0  Très bien
# 4                 Hotel de la Tour     8.2  Très bien
#
#                                            HotelLink
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        208 non-null    object
#  1   Rating      208 non-null    float64
#  2   RatingText  208 non-null    object
#  3   HotelLink   208 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 6.6+ KB

# %%
df_2 = pd.read_csv("hotels_with_address.csv")

# %%
df_2.head()
# Out:
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...
#
#                                              address        lat       lng
# 0  5 rue du 8 Mai 1945, 10e arr., 75010 Paris, Fr...  48.875950  2.358766
# 1     27 Rue Esquirol, 13e arr., 75013 Paris, France  48.834906  2.360376
# 2  23 Avenue René Fonck, 19e arr., 75019 Paris, F...  48.880018  2.408066
# 3  4 Rue De La Grange Bateliere, 9e arr., 75009 P...  48.873089  2.342492
# 4  19 boulevard Edgar Quinet, 14e arr., 75014 Par...  48.841197  2.323891

# %% [markdown]
# From this dataset we can get the exact address and also its coordinates (lat and lng), let s merge them to the other dataset using the url

# %%
merged_df = pd.merge(df_1, df_2, left_on='HotelLink', right_on='url', how='inner')

# %%
merged_df.drop(columns=['url'], inplace=True)

# %%
merged_df.head()
# Out:
#                               Name  Rating RatingText  \
# 0           NH Paris Gare de l'Est     8.1  Très bien
# 1       Citadines Austerlitz Paris     8.2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas     7.8       Bien
# 3  Best Western Hotel Opéra Drouot     8.0  Très bien
# 4                 Hotel de la Tour     8.2  Très bien
#
#                                            HotelLink  \
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...
#
#                                              address        lat       lng
# 0  5 rue du 8 Mai 1945, 10e arr., 75010 Paris, Fr...  48.875950  2.358766
# 1     27 Rue Esquirol, 13e arr., 75013 Paris, France  48.834906  2.360376
# 2  23 Avenue René Fonck, 19e arr., 75019 Paris, F...  48.880018  2.408066
# 3  4 Rue De La Grange Bateliere, 9e arr., 75009 P...  48.873089  2.342492
# 4  19 boulevard Edgar Quinet, 14e arr., 75014 Par...  48.841197  2.323891

# %%
df4 = pd.read_csv("hotel_details4.csv")

# %%
df4[
    (df4['all_reviews_text'].str.strip() == "") |    # Empty strings
    (df4['all_reviews_text'].isnull())               # NaN values
]
# Out:
#                                                   url  \
# 17  https://www.booking.com/hotel/fr/coypel.fr.htm...
# 88  https://www.booking.com/hotel/fr/terrass-paris...
#
#                                      full_description all_reviews_text  \
# 17  L’Hôtel Coypel by Magna Arbor est situé à seul...              NaN
# 88  Le Terrass" Hôtel Montmartre occupé un bâtimen...              NaN
#
#                                      rating_subscores
# 17  {'Personnel': 8.5, 'Équipements': 7.8, 'Propre...
# 88  {'Personnel': 9.5, 'Équipements': 9.1, 'Propre...

# %%
df4 = df4[~((df4['all_reviews_text'].str.strip() == "") | (df4['all_reviews_text'].isnull()))]

# %%
df4.head()
# Out:
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...
#
#                                     full_description  \
# 0  Le NH Paris Gare de l'Est est situé en face de...
# 1  Situé à mi-chemin entre le Quartier latin et l...
# 2  Situé dans le 19ème arrondissement de Paris, l...
# 3  Situé dans le quartier chic et central du 9ème...
# 4  Situé dans le 14ème arrondissement de Paris, l...
#
#                                     all_reviews_text  \
# 0  J’aime bien cette établissement par ce que ils...
# 1  Toujours la gentillesse dans l accueil!\nLa mo...
# 2  Un personnel accueillant,reactif,tres poli.Mem...
# 3  La prise en charge du personnel, la situation ...
# 4  Personnelle vraiment sympathique et petit déje...
#
#                                     rating_subscores
# 0  {'Personnel': 8.7, 'Équipements': 8.1, 'Propre...
# 1  {'Personnel': 9.2, 'Équipements': 8.1, 'Propre...
# 2  {'Personnel': 8.5, 'Équipements': 7.7, 'Propre...
# 3  {'Personnel': 9.0, 'Équipements': 7.9, 'Propre...
# 4  {'Personnel': 9.3, 'Équipements': 7.9, 'Propre...

# %%
print(df4.loc[0, 'all_reviews_text'])
# Out:
# J’aime bien cette établissement par ce que ils sont très bien accueillant
# Pas
#
# Tout en général vraiment un bel hôtel et un personnel au top et a l écoute du client
#
# La propreté et le confort
# Rien n’à redire
#
# super emplacement en face de la gare.
# Chambre confortable, lits très bien, douche et sdb agréables.
# Bouilloire en chambre (café et thé), coffre fort
# chambre donnant sur rue de la gare, donc un peu bruyant (surtout les bus)
#
# L'emplacement, la tranquillité, l'équipement
#
# l emplacement et personnel
#
# Emplacement idéal, accueil chaleureux, salle de bain confortable mais surtout petit déjeuner excellent
# Difficile d’améliorer mais la chambre(hors salle de bain) est si petite que tout est amassé.
#
# Proximité de la gare et station de métro juste devant. Hôtel est propre, le personnel accueillant, un rapport qualité, prix correcte.
# Le bruit de la VMC qui était juste insupportable pendant la nuit. Dommage.
#
# chambre un peu exiguë par contre la t° de l'eau chaude est très variable ce qui est gênant et désagréable ce n'est pourtant pas difficile d'assurer cela.
# LE PROBLEME DE L'EAU CHAUDE
#
# Chambre fonctionnel,propre,bien équipée., calme. Position géographique de l'hôtel avec proximité immédiate des transports en commun et de la Gare de l'Est
# Cout du petit déjeuner
#
# Hotel très bien placé en face de la gare de l'Est , métro au pied . Beau hall de réception , et bar accueillant . Chambre moderne , un peu petite mais très bien équipée . Lit confortable . Bonne insonorisation .
# Baignoire très haute à escalader pour prendre la douche , et surtout dangereuse quand on sort . La robinetterie du lavabo de ma chambre était défaillante .
#
# Confortable et bien situé
# Chambre un peu petite
#
# Sejour d une nuit en famille, avec un personnel a l accueil tres sympathique, la double chambre tres belle avec la vue sur la Gare de l Est, la salle de bain grande et lumineuse, la possibilite de laisser les bagages avant horaire d entree et apres heure de sortie, bref les enfants et moi-meme avons vraiment notre hebergement, le confort, la proximite train et metro au pied de l hotel, le quartier..
# RAS si ce n est le tarif du petit dejeuner, que nous n avons pas pu prendre.
#
# Tout était parfait. La décoration et l'aménagement de la chambre. Le personnel était très sympathique.
# Rien
#
# Hôtel de qualité. Bien situé (directement en face de la Gare de l'Est) et à proximité immédiate des transports en commun. Accueil souriant et professionnel à la réception. Chambre propre, confortable et très calme au 7è étage. Literie de qualité. J'y avais déjà séjourné il y a 1 an ou 2, quand il était sous enseigne Holiday Inn et je n'avais pas été spécialement emballé à l'époque(chambre petite et vieillotte).
# Rien à redire.
#
# Bonne localisation et bon confort.
#
# La proximité de la gare de l'Est
# La propreté
# La petite surprise demandée lors de la réservation
# Le confort du lit
# La vue de la chambre
# Rien. Tout était comme attendu.
#
# Emplacement en face du métro et de la gare de l'Est
# Surclassement dans une suite
# Chambre calme et confortable
# Personnel attentif
# Le distributeur de savon ne fonctionnait pas bien
#
# L'emplacement
# Le rapport qualité prix
# Le personnel pro aimable
#
# Très bon emplacement
# La chambre étant au dernière étage était mansardée et assez petite
#
# Bonne literie; salle de bains fonctionnelle et spacieuse, tout comme la chambre en elle-même; très joli buffet petit-déjeuner; personnel très sympathique.
# rien à redire
#
# Je recommande cet hôtel.
#
# Décoration de la chambre, la salle de bain est très jolie et fonctionnelle
# La literie est beaucoup trop ferme et les oreillers manquent de gonflant
#
# Nous adorons cet hôtel et le personnel! Ils sont tous bienveillants, professionnels et attentifs. L’emplacement est phénoménal juste à côté d’un iconique restaurant bistrot et la gare/metro.
# Pour rendre l’expérience encore meilleure, je suggérerais d’améliorer la propreté des chambres afin qu’elle soit au même niveau que le service remarquable offert par le personnel de cet hôtel 4 étoiles. Cela permettrait d’assurer un confort optimal à tous les clients. Merci encore pour votre hospitalité
#
# Face à La gare
# La demande de caution de 28euros que j'ai refusée
# Certains équipements ds la salle de bain descellés
#
# Le personnel est professionnel et accueillant. En outre, j'ai bénéficié d'une dérogation pour occuper ma chambre à l'arrivée avant 15h
# Deux nuits successivement, le système d'alarme incendie s'est déclenché indûment. Ce qui a provoqué à tous les coups, une panique générale parmi les clients
#
# Hôtel parfaitement situé, juste en face de la Gare de l'Est, chambre propre et personnel chaleureux. Hotel silencieux et calme.
# Il faisait trop chaud dans la chambre, malgré un thermostat baissé, vraiment dommage.
#
# Rapport qualité prix, proximité avec gare du Nord et gare de l'Est
# État de la salle de bains qui aurait mérité une remise à neuf
#
# Chambre et salle de bain confortables.
# Le petit déjeuner n'est pas à la hauteur; le chauffage faisait du bruit; la baignoire qui glisse; on voit que l'hôtel est un peut abimé quand on prend le couloir qui mène aux chambres.
#
# Localisation, personnel compétent, chambre avec les équipements essentiels, chambres propres et récentes
#
# bien situé
# personnel super gentil
# bagage facile pour garder
#
# Son confort
# Rien du tout
#
# la chambre était très propre et correspondait a nos attentes
# rien
#
# Satisfait
# ??
#
# Situation
# Prix des petits déjeuners
#
# Tout. L accueil la chambre la qualité de la literie et le petit dej.
# Le bruit de la rue mais la l établissement ´ y peut rien…,
#
# Nous avons passé un excellent séjour dans cet hôtel à Paris. L’endroit est magnifique, et l’accueil a été incroyable et chaleureux. Le personnel était toujours prêt à nous aider, rendant notre séjour très agréable. La chambre était confortable, stylée, et d’une propreté irréprochable. Nous avons adoré l’ambiance de l’hôtel !
# L’hôtel est idéalement situé, à deux pas du métro et de la gare de l’Est, ce qui est très pratique pour se déplacer dans Paris. Nous n’avons pas eu l’occasion d’essayer le restaurant de l’hôtel, mais il y a de nombreuses brasseries à proximité pour le petit déjeuner, le déjeuner et le dîner. Juste à côté, il y a une célèbre brasserie parisienne, réputée pour sa cuisine traditionnelle française, parfaite pour découvrir de vieilles recettes de brasserie.
# Le seul inconvénient de notre séjour a été que notre voisin de chambre laissait souvent sa porte claquer en rentrant et sortant, ce qui nous a réveillés à plusieurs reprises durant la nuit.
#
# rien a dire
# rien a dire
#
# L'offre au petit déjeuner est très complète.
# La chambre était très silencieuse.
# Cabine de douche très spacieuse et douche très pratique d'utilisation.
# On ne pouvait pas ouvrir totalement la fenêtre de la salle de bains.
# Pour la vasque de la salle de bains, le mitigeur était inversé (vers le rouge, on avait plus d'eau froide).
#
# L’accueil, la chambre la vue
# Le WC est coincé derrière la porte de la salle de bain la moquette au sol
#
# Le calme. On entend rien
# Une petite salle de bain pour une suite
#
# personnel tres serviable
# l'etat des chambres: finitions
#
# L’emplacement
# La saleté de la douche
#
# La situation à deux pas de la gare de l'Est
# Le tarif imbattable
# Le personnel serviable
# La chambre certes petite mais très fonctionnelle, propre et calme
#
# Le petit déjeuner. Scrambled eggs très bien.
# Moquette avec taches
#
# Proximité métro et Gare de l’Est
# Personnel aimable
# Petit déjeuner trop cher
#
# Accueil excellent, petit déjeuner copieux et varié. Localisation en face de la gare de l Est.
#
# La disponibilité et la serviabilité du personnel de l'hôtel ainsi que le petit-déjeuner.
#
# emplacement idéal,
# la chambre était confortable.
# Le personnel agréable
#
# L’emplacement est bien situé
# Une caution a été demandé par la réception du montant de 100 euros sans signe et information pendant la réservation
#
# Le personnel est très accueillant et disponible.
#
# Confort propreté
# Chambre avec vue face au béton , Nous n'avons pas appréciés ¹
#
# Le buffet du petit-déjeuner copieux, varié avec un personnel très accueillant. Café excellent, faut dire que la machine est super. La consigne des bagages et la disponibilité du personnel
# La taille de la chambre et de la salle de bains, plus de patères
#
# Propreté calme
# Petit déjeuner copieux
# Rien
#
# L’emplacement
# Un extra payé pour avoir une chambre à 30 min avant le Check in. Après un voyage de 28h sans dormir.
#
# Localisation imbattable !
# Personnel de service serviable.
# Bouteilles d'eau offertes.
# Clé électronique n'a pas marché la première fois que j'ai accédé à ma chambre, j'ai dû redescendre à la réception pour qu'elle soit reprogrammée
# Je ne suis pas arrivée à faire marcher la télévision dans ma chambre, heureusement pas eu besoin.
# Pas de plateau avec bouilloire, thé, tisane.
#
# Face a la gare
#
# Modernité de la chambre.Confort de la literie.
# J ai apprécié la bouilloire, tisane et café dans la chambre.
# Proximité des restaurants de la gare, du metro.
# Je n ai pas aimé le prix du petit déjeuner, trop élevé. C est le prox d un diner avec boisson au restaurant d a côté.
#
# Proximité immédiate avec la gare, quartier animé
# Chambre petite et salle de bain également, mais c'est Paris ! Très moderne par contre
#
# Très bien situé,juste devant la gare de l'est,très bien isolé et confortable
# La demande pour être réveillée n'a pas été réalisée.dommage!
#
# En FACE de la gare, c'est incroyable ! Vraiment imbatable sur ce point et ils le savent très bien donc les prix sont souvent plus élevés qu'à côté.
# L’ascenceur est pas fou fou, il grince un peu mais en vrai tant qu'il fonctionne c'est top.
# Le petit déj est d'un prix....assez élevé. alors c'est compréhensible lorsque l'on l'on sait qu'il est à volonté mais bon je n'ai pas envie d'avoir à passer 3H au petit déj pour le rentabiliser hahah
#
# Acces facile. Personnel a l'ecoute. Literie parfaite et excellente.
# Salle de bains petite, avec un accès pas pratique pour fermer la porte .Pas de rangements. Bonne douche
#
# rapport qualité prix et personnels sympas
# fenêtre côté cour mais ça m'a pas empêcher de faire une bonne nuit...
# prochain fois je demanderai côté rue... pas un point négatif juste a demandé aux réceptionniste
#
# L'amabilité du personnel.
# Le petit balcon ( chambre au 6eme )
# L'état de la moquette dans la chambre
# L'absence de machine expresso.
#
# Établissement nettement plus propre que ces dernières années
#
# Emplacement, accueil du personnel
# Petit souci avec l’écoulement de la baignoire
#
# Chambre sur cour au 5 eme donc très calme
# Rien
#
# Excellent emplacement en face de la Gare de l'Est et devant une bouche de Métro.
#
# hôtel bien situé, personnel sympa
# chambre très petite
#
# J’ai aimé l’a proximité avec les transports en commun la tranquillité.
# Le faite que j’ai oublié des trucs on m’a pas appelé et je suis passé à l’accueil on m’a pas pu me renseigner clairement.
#
# Personnel accueillant et chaleureux, emplacement idéal, confort et propreté.
# Chaînes télé payantes malgré le prix de la chambre, manque récurrent de peignoir et clés désactivées en permanence.
#
# L’accueil très agréable
# Chambre avec très belle vue
# Calme la nuit
# Lit très confortable
# La chambre sentait très fort le moisi (humidité)
#
# L'emplacement : juste en face de la gare et de notre restaurant préféré : le bouillon chartier
# L'amabilité du personnel
# Rien de spécial
#
# L’emplacement, l’accueil, le confort
#
# La chasse d’eau de la cuvette, des toilettes inefficace
#
# Chambre
# Proximité
#
# Une partie du personnel pas du tout professionnel n'y sympa.
#
# Bon emplacement.
# Personnel agréable.
# Rien à signaler.
#
# La chambre était parfaitement conçue pour avoir tout ce qu'il faut pour séjourner sans problème. Sauf le wifi.
# connexion wifi
#
# L accueil la chambre les petites attentions à la réception ( jus sucrerie ..).
# La 1ere chambe n était pas celle demandée mais rapidement on nous a changé de chambre
# Taxe de séjour cher
# Et la caution est trop élevée à mon goût
#
# L'emplacement, face à la gare de l'est. A proximité d'une station de métro (même pas 10 mètres).
# La chaleur de l'eau de la salledebain( très important pour moi). Les boissons à l'accueil : jus d'orange, eau citronnée et des bonbons 😊
# Les oreillers, trop durs à notre goût.
#
# en face de la Gare de l'Est , A coté du Metro, nombreux restaurants, chambre au 6eme pas de bruit
# petit déjeuner beaucoup de choix.
# mérite une rénovation des couloirs et ascenseurs
#
# Très belle chambre et sdb
# Accueil un peu froid...
#
# Proche des gares de l’Est/Nord
# Disponible 24/24, le checkin peut s’effectuer dans la nuit
# Le prix est légèrement trop élevé
#
# oui
# le mini bar prix inaccessible
# plafond
#
# L'emplacement de l'hôtel et le professionnalisme du personnel...toujours à l'écoute du client.
# Seul petit bémol...la disposition des chariots en pecmel dans le couloir...un arrangement plus ordonné serait un plus.
#
# literie + peignoir
# rien
#
# Trop loin, j'ai déjà oublié.
# J'ai apprécié la proximité du Bouillon Chartier qui proposait de la langue de boeuf, un plat que j'apprécie mais qui est devenu rare à Paris.
#
# situation face gare de l'est - proximité metro - confort- bar du rez de chaussé- amabilité du personnel
#
# Localisation
# Personnel disponible
# Réservation non conforme à la demande
#
# Chambre confortable
# Petit déjeuner de très bonne qualité
# RAS
#
# Hôtel en face de la gare de l'Est
# Chambre et salle de bain bien équipées
# Petit déjeuner au top : énormément de choix
# Bouche de métro jusque aux pieds de l'hôtel
# Je ne vois rien ..... hormis que l'enseigne est peu visible.
#
# Le petit déjeuner
# Le bruit de la VMC
#
# Son as cessibilité, personel et attention
#
# Le lit confortable et la chambre très silencieuse
# La caution de 50 € en plus du prix de la chambre qui peut bloquer les autres règlements
#
# L’emplacement, la propreté et l’accueil
# Le petit déjeuner n’est pas inclu dans les frais de chambre
#
# A l'accueil,
# À l'accueil, les personnels, pas du tout sourient, pas d'excuse pour une longue attente pour scanner ma carte d'identité.
# Une couverture pas assez coude (vous pouvez mettre une deuxième).
#
# Proximité de la gare. Vues sur Paris aux étages supérieurs.
#
# C'était pas mal...propre;
# La chambre n'était pas réchauffée il faisait très froid
#
# Facilité de déplacement, tout à disposition dans la proximité
# 2 peignoirs pour 3 personnes, 1 brosse à dents pour 3, alors qu'on a réservé pour 3 personnes c'est bien dommage très déçu sur se sujet en plus faire payer un peignoir alors que nous réservons pour 3 personnes !!!!
#
# Déçu par le fait que la réservation consistait en une chambre à 2 lits, et à l'arrivée nous avons eu une chambre à un lit double sans être prévenu et sans dédommagement.
#
# Bien situé au cœur de Paris dans un joli quartier. Hôtel propre et confortable. Personnel serviable et souriant
# Tout était parfait
#
# bon accueil ,chambre spacieuse ,coté entrée un lit clic clac pour notre pte fille 17ans avec porte de séparation super
# bon buffet pte déjeuné et personnel professionnel
#
# Le personnel souriant et serviable
# Rien
#
# L’emplacement est idéal et la chambre confortable
# Le bruit de la rue dehors et la fuite de la douche parce qu’il y a un espace en dessous de la porte qui laisse passer toute l’eau
#
# Le cadre est agréable et bien desservi et proche de tous
# Les environs apprécie moins mauvaise fréquentation
#
# La propreté
# Ils faisait très chaud dans la chambre ma fille elle arrivait pas à dormir 🥹
#
# Emplacement de la chambre
# Vincent à l'accueil était génial !
# Qualité wifi
#
# Emplacement
# Offre des chaînes de télévision
#
# La localisation
# Le prix
#
# PERSONNEL SYMPA ET CHAMBRE AGREABLE
# PETIT DEJEUNER CHAR MAIS OK
# LE PETIT DEJEUNER EST CHER
#
# La moquette sale et trouée par des cigarettes dans la chambre
# La fenêtre qui ferme mal
# La bonde du lavabo HS
# L’accueil style commissariat de police, ma carte d’identité a été scrutée un long moment
#
# Très petite chambre avec salle de douche très très petite
#
# Emplacement très pratique ! Petit déjeuner super. Et le service était parfait.
# La chambre manque de propreté à certains endroits, surtout au niveau de la salle de bain.
#
# L'hôtel est très bien situé, juste en face de la gare de L'est. Le personnel est bienveillant, la chambre était très propre, un point important pour moi et ce qui nous a permis de nous reposer après notre trajet. J'adorerais le décor. Nous avons également profité de magnifique bouteille de vin offert par l'hôtel. Le lit était confortable et très propre. Nous y vont retourner avec les enfants pour la prochaine fois.
# Merci
# Le seul bémol c'est le SDB. Après une douche le sol reste un peu humide. Sinon il est super beau et spacieux.
#
# Hôtel très bien situé. Literie propre et confortable. Petit-déjeuner varié.
# RAS.
#
# L'emplacement
#
# Tout
# Nettoyage des moquettes et des baignoires
#
# Petit lit
#
# Emplacement idéal en face de la gare et à côté du bouillon Chartier !
# La salle de bain serait à entretenir : joint de salle de bain, porte pq ne tient plus
#
# l'hôtel est bien situé , c'était comme j'aime bon service
#
# Les chambres propres et fonctionnelles, avec plateau bouilloire pour thé et café à disposition.
#
# Petit déjeuner copieux et variés.
#
# Le personnel est dévoué et accueillant !
#
# L amabilité du personnel, propreté de la chambre
#
# Face à la gare de l'est, on traverse juste la rue pour y être. La chambre est bien équippée, il y a même une table + fer pour repasser, des cintres, bouteilles d'eau & thé pour l'arrivée, mini-bar.
# Service de bagagerie disponible, check-in facile. Le petit déjeuner était très varié, vraiment appréciable.
# Pas grand chose. Pour les chambres face à la gare de l'est, ça peut être un peu bruyant le soir avec la multitude de taxis qui klaxonnent, mais ça s'arrête vite, j'ai plutôt bien dormi. Les teintures dans les ascenceurs sont un peu vétustes.
#
# Amabilité du personnel La personne de l’accueil nous a proposé une chambre spacieuse ( notre séjour étant de 6 nuits)Ce qui n’était pas prévu
# Rien
#
# Bruit de VMC impossible à arrêter
#
# très propre et confortable
# rien
#
# Chambre standard,petit mais cosy,bien pour une où deux nuits, sinon trop petit.
# Tout était propre,bien équipé, très bon lit.
# L'hôtel est super bien placé juste en face de la gare de l'est ,devant l'établissement se trouve la station de Metro,connection direct avec tout Paris et à côté il y a des très bonnes Restaurants qui font également le petit déjeuner à un prix raisonnable.
# Après le check out on peut laisser les bagages au storage room jusqu'au départ de Paris .
# Sans aucune hesitation je retournerai à cette Hôtel pour mon prochain séjour à Paris.
# L'espace du WC dans la salle de bain,il ne faut pas être corpulent, sinon quasi impossible de s'assoir sur le WC dans le bon sens.
# Le prix de 25€ pour le petit déjeuner par personne est à mon goût trop élevé.
#
# Le personnel
# Hôtel en cours de rénovation...( mal faite ). Réveillé à 8h du matin par des perceuses , coup de marteau...... grooos travaux dans l'hôtel ! Horrible. Problème de chauffage...trooop chaud même éteint. On s'est réveillé le nez et gorge sèche
#
# Accueil, propreté des lieux
#
# Tout
# Tout, personnel plus qu'agréable, chambre nickel
#
# Personnelles à votre écoute
# De très belles chambres,
# Tout était parfait. Merci pour votre accueil.
#
# Chambre sympa, les bouteilles d'eau offertes sont toujours bien venues quand on doit marcher plusieurs KM dans Paris.
# Salle de bain très très petite, on peut à peine fermé la porte derrière (mais bon, c'est Paris)
# L'organisation du personnel :
# - arrivée à 13h, la chambre n'est dispo qu'après 15h ! (sinon il faut payer héhé !). A cote de ça, une personne du ménage est rentrée dans ma chambre à 10h50 pour nettoyer le jour de mon départ !
# - Le réceptionniste ne trouvant plus ma valise, m'a demandé de le suivre dans les couloirs de l'hotel (reservé aux personnels) puis finalement m'a laissé la-bas après avoir récupéré mon sac ?
# - Quand j'ai souhaité déposer mon sac en consigne, le personnel m'a demandé de l'accompagner et de le déposer moi-même car il était chargé (d’accord ?).
#
# Confort. Situation excellente
#
# Tout personnel très agréable chambre charmante et propre + enface de la gare rien à dire un hotel a tout ses attentes
# Prix du sack bar très élevé
#
# L’alarme incendie a 1h du matin qui m’a coupé mon court repos de la semaine
#
# Tout. Le rapport qualité-prix. La situation face à la gare de l'Est. La chambre très fonctionnelle. Le grand bureau. Les facilités de rangement. Le plateau-bouilloire, le minibar. La douche à l'italienne. L'amabilité du personnel.
#
# L’hôtel ne mérite pas 4 étoiles
#
# Très bien
# Tout
#
# Tout était parfait et adapté à mes besoins.
# RAS
#
# Chambre de 10 m2 pour 178€
# Inadmissible
#
# Le calme, la propreté, la proximité avec la gare
# Rien, tout était parfait
#
# Tout
#
# Personnel agréable, lit assez confortable
# Chambre petite et vieillissante, petit déjeuner cher
#
# RienPas d'eau chaude. Des tâches sur le canapé. Petit déjeuner pauvre et tables non débarrassée. Beaucoup trop cher pour la qualité.
# Tout
#
# sa situation proche de la gare, ce qui a conditionné mon choix
# la vetusté des portes , et equipements sanitaires , home staging grossier de la salle d'eau
# bonne literie
#
# Tout m’as plus c’est exptionelle
# Rien parfait
#
# L'emplacement et la bagagerie
# Rien
#
# La proximité avec la Gare de l’Est et les autres lieux
# Le personnel d’accueil / réception , lors de l’enregistrement , peu aimable, je dirais même impoli
#
# L’emplacement face à la gare et le métro à côté
# Il manquait un boutons à une lampe. On pouvait donc pas l’allumer. Le lit trop dur. On entend tout le bruit dans le couloir et dehors surtout la nuit.
# Pas de place dans la salle de bain pour poser les affaires. La poussière pas faite.
#
# Train le matin à 6h36 , aucun petit déjeuner avant 6h30 !
# Une aberration à Paris, dans un établissement situé face à une gare ... dans l'obligation donc de le prendre à la gare où des enseignes déjà ouvertes ( si, si !) nous ont chaleureusement accueillis .
# A noter surtout que les petits déjeuners avaient déjà été réglés à la réservation et qu'aucun remboursement ou dédommagement ne m'a été proposé !!!
# Petit profit...
#
# Accueil chaleureux, l’hôtel sent bon
# Trace de peinture sur la fenêtre, moquette brûlée, oublie mon jus d’orange et mes tranches de poulet lors du petit déjeuner en chambre…
#
# Très bien
# Ras
#
# Super!!! Conforme
# Rien!!!
#
# Lit confortable et vue agréable, et personnel très professionnel, vraiment rien à dire là dessus.
# Chambre minuscule, climatisation quasi inexistante, c’était vraiment contraire à nos attentes pour le prix et vu ce que l’hôtel prétend vendre.
#
# Très bon emplacement en face de la gare. Chambres Très confortables et personnel efficace. Chambre bruyante avec la proximité de la circulation près de la gare
# Le bruit
#
# Le personnel du matin était agréable
# Très mauvais accueil le soir à l'arrivée. J'ai trouvé que le réceptionniste n'était pas professionnel du tout.
# Son comportement était à deux doigts de l'irrespect.
# Le système de climatisation était inefficace et bien trop bruyant.
# Les chambres sont aussi isolées qu'un Formule 1. On entend tous les bruits dans les couloirs, à commencer par les portes qui claquent en permanence.
# On n'est bien loin d'un nh hotel.
# Aucun chargeur de téléphone mis à disposition des clients alors même que la pub de ce service et placer dans l'ascenseur et les chambres....
# Un manque d'investissement réel sur le sujet.
#
# Service exceptionnel et petit déjeuner au top
# Tout était ok
#
# Rien
# Ce sont des escrocs !
#
# Top !
# Rien
#
# L'accueil
# Petite chambre
#
# L’emplacement le confort
# L aceuil le personnel des voleurs
#
# Chambre bruyante; dans la salle de bains une aération fonctionne en permanence et elle est indébranchable; bon petit déjeuner, mais finalement trop cher.
# De nombreuses chambres ne garantissent pas la tranquillité! soit il y a des métros qui vrombissent toutes les 2 à 3 minutes (même la nuit) soit il y a la ventilation/soufflerie de la clim collective de l'hôtel qui hurle toute la nuit et empêche d'ouvrir la fenêtre.
# L'hôtel n'a tenu compte en aucune façon de mes préférences, Ils s'en sont foutu. Décevant.
#
# La gentillesse du personnel et la propreté
#
# La décoration est très jolie, il y a des bonbons à l’accueil et on nous en apporte aussi à notre chambre ce qui est une gentille attention surtout avec les enfants. Le petit déjeuner est fabuleux. Rien à dire je recommande cet hôtel
# Ras
#
# Tout a été conforme à mes attentes. J'ai été te ravie de mon séjour.
# RAS
#
# Accueil pas à la hauteur, caution de 50€ !!!
#
# La deco, la propreté
#
# proximité de la gare métro/taxis
# trop impersonnel
#
# Non
# La mauvaise foi
#
# Personnel très serviable et agréable
# Emplacement top
#
# La proximité de l'endroit, et très bien desservie. Hôtel prope et personnelle agréable.
#
# Chambre vieille
# Sdb avec joints noirs et abîmés
# Barre de seuille de ma chambre cassée (attention à ne pas tomber )
# Installation dans les communs rudimentaires.
# Pas de bouilloire dans les chambres.
# Mauvaise expérience pour une micro nuit de 4h.....
#
# Confortable, propre. Juste en face de la gare de l'est.
#
# L'hôtel situé à côté de la gare et de la station de taxi c'était impeccable
# Ce que j'ai pas aimé c'est la taxe de séjour, la moquette de la chambre c'était sale et le bruit du métro tu peux pas dormir le wi-fi dans la chambre ne fonctionne pas
#
# Emplacement idéal quand une connexion est à faire avec la Gare de l'Est et grande amabilité du personnel du petit déjeuner.
# Salle de bains agréable ainsi que la décoration de la chambre
# L'enregistrement à l'arrivée a été long (problème pour retrouver notre réservation alors que nous avions appelé le matin même pour nous assurer que tout était en ordre)
# Bar fermé à 22:00 alors qu'annoncé ouvert (nous n'avions pas mangé, la seule solution était de ressortir ...)
# Le confort du lit additionnel (canapé lit) reste à désirer pour un adulte
# L'état général de l'hôtel aurait besoin d'un rafraichissement, notamment l'isolation phonique pour les chambres donnant sur l'extérieur (forte nuisance due au trafic)
#
# Hôtel 4* design confortable bien placé avec vue sur la belle gare de l'est, près des restaurants, avec un personnel aux petits soins. A+++
# RAS
#
# L'accueil, depuis le portier jusqu'au barman, en passant par le desk central !! Tous très professionnels.
# La propreté de la chambre.
#
# Proximité gare
# Accueil du personnel
#
# Acceuil et gentillesse de l’equipe
# Rien
#
# Chambre propre et fonctionnelle hôtel réservé avant de prendre un vol a Orly pas très loin du sacré coeur et juste a coté du bouillon chartier ou nous nous sommes régalés on y reviendra pour quelques jours cet automne merci beaucoup
#
# Le personnel a l'accueil très professionnel et agreable, la chambre très propre. c'est notre deuxième visite, qui malheureusement a été gâché par un service désastreux aux petit déjeuné
# Le petit déjeuné était un désastre. nous sommes arrivé a heure il restait 3 saucisses un ou deux morceaux de bacon et les oeuf brouillé nageait dans un liquide. il a pris 15 minutes pour qu'il rafraîchisse le buffet avec des saucisse et du bacon cuit en vapeur.
#
# Personnel disponible et attentif à nos demandes.
#
# La convivialité du personnel .tout était parfait
# Rien à dire
#
# Personnel au petit soin
#
# Literie correcte, propreté tout à fait okay, espace petit mais fonctionnel.
# entrée de l'hôtel rendue un peu difficile à cause des personnes hélas en difficulté (SDF, personnes de la rue). Un agent de sécurité est là mais l'ambiance de l'entrée est peu engageante. L'hotel devrait peut-être s'organiser pour trouver des solutions pour ces pauvres gens sur le trottoir, peut être quelque chose de créatif, afin de rendre le tout moins malaisé ?
#
# Staff was very kind and helpful
# Location was a bit rough and my room was looking to a wall
#
# Location was great for us, walking distance to the train station for other destinations, room is spacious to what I am used to see in Paris
# The smell in the breakfast area
#
# Location
# Pretty small
#
# Loved the convenient location right beside train station! Also, staff were exceptionally helpful and offered interesting suggestions.
# The size of the room was small, yet, for a simple night's stay where I needed a base, it was fine.
#
# Decor
# Room allocated was different from room booked
#
# It ia better if there is room slippers
#
# Great location
#
# Perfect location.
#
# The location was excellent, conveniently close to the train and metro stations. The staff was exceptionally helpful, with special recognition to Asher for assisting me with the birthday parcels delivered to the hotel. I’ll definitely return!
#
# Unexpectedly had a gorgeous balcony room with views of the Eiffel Tower. My mum had informed them that it was my birthday and we were given muffins, balloons and a note. It was a lovely touch. The hotel felt safe, the staff were friendly and the room was very clean. It was also great location right by the metro, would highly recommend.
# N/a
#
# Excellent location, helpful staff and great breakfast. I’d stay there again!
# The hotel doesn’t have a gym.
#
# Location is superb, near to main train Station and restaurants.
# Small room.
#
# Metro just outside. Nice eating and drinking places nearby.
# The scaffolding outside but realise the work had to take place.
#
# Check-in process was seamless, best breakfast I must say. The location is very accessible and is in the core of the city. Staff was well spoken and well behaved they helped us for whatever we asked.
# the room size is a bit small, the washroom could have a better drainage system as the water that spills out of bathtub, enters directly into the room.
#
# Friendly staff, good location, great bathroom!
# Quite small room and not very soundproof - can hear people walking past your room late at night.
#
# Friendly Staff, central location and comfortable rooms. Excellent service.
#
# Great location
# Housekeeping attended our room even though we left a Do not disturb sign at the door
#
# Great property,excellent location,great family room. There is a water and some fruits and candies offered at the lobby. Nice view. Breakfast for extra pay was nice. Lots of restaurants and food options around the area and the metro, trains, shops as well
# Front desk/ customer service is nice too.
# I would come again
# The shampoo, conditioner and soap at the bathroom is hardly possible to collect from the push pump. I understand the hotel is trying to save but that's too little.
#
# The hotel was located in a great location next to Garu du nord and the metro station is right in front of the door. Staff very welcoming and friendly.
# Even if the reception of the hotel looks nice, I don’t think it’s a four star hotel. The room was too small and the carpet was quite dirty and covered in stains. You couldn’t walk without slippers or shoes on it and the hotel doesn’t provide any slippers.
#
# Ligging toc centrum, metro en trein
#
# The greeting was very warm and welcoming and our room was ready from 10am! A very comfortable bed and a very quiet room. The bath and general facilities were great. Breakfast was very good indeed, with a good choice for everyone.
# The toilet seat was loose and the room decor felt a little tired with chipped doors etc.
#
# The location was great since it's really close to the Metro and both the train stations. I also like coming to fresh sheets and towels too! I recommend this place especially if you're planning to go to Disneyland or other cities and towns just outside Paris.
# The carpet was clean but feels a bit dirty to be walking barefoot so I wished they provided slippers. And the room was a bit snug for 2 adults. But unless you're planning to stay in the hotel during the day. It's not an issue at all.
#
# Spacious room with a lovely view
# Our bathroom sink wasn't draining properly
#
# Breakfast was awesome...The personel was nice and available..I really enjoyed having breakfast there..
# It is a nice place..Very clean..
#
# Location is just across Gare de l’Est station; good base for sightseeing. Although showing some signs of age, the rooms were comfortable and had enough amenities for my needs.
# I did have a few reservations about safety because the lobby entrance was right on the sidewalk which had a lot of foot traffic, and it was easy to get in and out of the hotel. However the lobby was adequately staffed during my stay.
#
# The team was friendly and accommodating overall, but on one of the nights, I lost a backpack. The next day, I asked the gentleman at the reception if they could check the cameras to see if I returned with the backpack. The response I received was that they would need the police and a formal justification to review the footage. I didn't ask to view the footage myself—just to confirm whether I had returned with the backpack. I felt a bit disappointed that they didn't try to help more and instead gave what seemed like an unnecessary excuse. However, the location is excellent, the check-in team was friendly, and the room was adequate.
# .
#
# I love this hotel, and have stayed here 4 times now. Great breakfast buffet. Comfortable rooms. Great view of Sacre C cathedral to wake up to each morning! Ideal location for train connections, and restaurants. Will stay here again and again. Wish it could still be booked via British Airways holidays. However, because of enjoyable stays at the hotel before, it was worth booking it separately to my flights.
# My room, 602, was smaller than i have had in the past.
#
# The breakfast was good. Lots of choice and fresh. The metro is just outside as are some very good restaurants.
#
# Nice staff and good location opposite The station (gare l’est)
# quite small room
#
# Location, it is directly across the street from the Gare de L'Est station, and even a few minutes from Gare de Nord, nice décor.,
# cooling wasn't good, room didn't cool down and fan very weak. Since it was Oct we opened the window but we were on street side so noisy with window open. Also although not fault of hotel, someone was smoking and the alarm when off when we were sound asleep. Needless to say it was a rough night.
#
# Staff was polite
# Breakfast was not at all good. No live counter & no much options. Not fulfilling value for money.
#
# The room service is bad. Water bottles were not refilled on daily basis. They give water complementary only at the time of check-in & other days you have to buy.
#
# Lovely comfortable room and breakfast. The fresh clean bedsheets smelled gorgeous and the bathroom although small was really modern and nice.
# I wish there was a restaurant on site or the ability to order a sandwich or something.
#
# The property is so nice and ever they cleaning our room! And also clean
# One thing I notice not actually I don’t but the toilet bowl it’s high, sorry for that
#
# Right across the street from Gare de l'Est. Great
# I guess like most, if not all, older European hotels, the room are horribly small, especially if staying more than one night. But cleanliness and great staff made the room size just a minor thing, all good
#
# the spacious room, comfortable bed, exceptional help from a gentleman in reception who ran some way after me to give me a map which he had printed off for me. Much appreciated!
# Some noise from trains. a bath with shower rather than a walk- in shower
#
# The hotel overall is nice, breakfast is tasty and staff very helpful. The location is excellent to explore all of Paris from, and right next to the very hip Canal St Martin!
# The room is a bit small so didn't spend much time there aside from sleeping and showering.
#
# close to train/metro stations, fair breakfast with some gluttenfree options. The view from the room was at Eiffel Tower. The size if the room was quite good with small terrace
#
# Location, next door to metro.
# Easy access to local amenities.
# Nothing of importance
#
# Top location, nice staff, quiet rooms and modern rooms. Great value for money.
#
# We were allowed to check in early. Many thanks to Xavier
# The room and the toilet is so small
#
# The cleanliness and staff are both top-notch. The buffet breakfast was also very good. The location is equally fantastic with the Metro or Buses and even walking distance to most of what you'd want to visit
# The only gripe is that the air con always blew cold air even when the thermostat was set to 25°C or even 30 ! With an infant, we wanted the room to be warmer and could not achieve that.
#
# I like NH properties. This hotel location was great since we were leaving from Gare dl’est. However it was a bit loud on the street. Otherwise nice.
#
# Nice location just opposite to Metro station with different types of restaurants around
# Staff are friendly and helpful
# Room size is just enough for two people and not much spacious
#
# The hotel is in a highly convenient location, looking out over Paris Gare de l'Est station.
# The room was clean and comfortable.
# Very small room considering the high price. OK for one night.
# I was surprised to be asked to pay extra for my wife's breakfast, even though I gave two names for the room.
#
# The best location…trains , metro, bus, everything is around, loved the number 32 bus which goes till the Eiffel, lots of restaurants nearby , the hotel staff are very helpful, they guided me about where to buy public transport tickets and places nearby…always willing to help staff is a big advantage in an unknown city…
# Nothing
#
# Great Location
# Good Breakfast
# Super friendly staff
# Horrible Internet connection you are cut out of the world most of the time
# Avoid rooms in first floor : Poor mobile signal - Noisy because of the restaurant
# Poor room amenities
#
# Breakfast too expensive, Wifi not working at all
#
# Ok - friendly ish
# City centre sp expemsive (but all hotels are these days)
#
# Hand location near the station. Room and bathroom small but stylish and suited our needs as we were not planning to spend much time in the rooms.
#
# Location and staff
# Room was clean and comfortable
#
# The location is excellent, it's directly in front of Gare de l'Est. The staff were really helpful and provided lots of information when we asked. The rooms were good size, clean and comfortable. It met out expectations.
# Nothing. We stayed for one night and all went well.
#
# Comfy. Room, very good breakfast, attentive and courteous. Staff.
#
# Very close to metro station .
# Nothing to dislike
#
# Location and cleanliness
# Key was not worked once during the stay.
#
# Everything is good. But they told us that the 1st day we have two free bottled water that never happened we dont have bottled water in our rooms.
#
# Charming staff on reception, location was perfect for us, directly opposite the Gare de l'Est.
# The room was small but it was clean and fine for one night's stay.
#
# Very comfortable and had all the things you need!
#
# Friendly welcoming staff
# Stylish rooms
# Lovely smell in the hotel
# Comfortable beds
# Clean
# Luggage storage
# Great location
#
# Perfect location, and loved the accessibility of the balcony decent vue of central! Staff were very lovely and spoke great English so no miscommunication and very helpful especially when I forgot my travel adapter, Really enjoyed my stay and will be booking this hotel again when I visit Paris again.
# N/A
#
# Location right across the Gare de l’Est as I was on an overnight visit to the city.
# Staff is generally helpful for guidance and tips.
# Size of the room is very small, no views.
# No issues like noises at night though.
#
# As someone travelling via Paris Est, the location could not have been better! There is an entrance to the metro directly outside, so it was perfect for travelling elsewhere too.
#
# The staff were outstanding, I really appreciated the welcoming and helpful attitudes I experienced from every staff member!
#
# The breakfast was also good. The options were varied and plenty of good pastries were offered, in addition to scrambled egg and other warm options.
# I didn’t experience any serious problems during my stay, although I think the drainage for the bathroom sink and air conditioning might have needed a bit of maintenance. They still functioned correctly, so this may just be a part of running a large hotel in an old building.
#
# Modern look of the room, right size and design. it was definitely good cleaning.
# communal areas still old style and need some refresh.
# check in policy to get the room earlier. The room was available before 15, but they ask €49 for it. Quite disappointing for NH considering the outrageous price during the Olympics.
#
# Room was large enough, bed was a bit too small for two parents.
# Breakfast was delicious and lots to choose from.
# Location right at Garde L'Est was excellent
# The double bed was a bit small for even two adults
# Otherwise the room and location met our expectations.
# Staff was friendly and was able to communicate well in English.
#
# Location
# Service in some area
#
# The staff were very polite and helpful and the rooms were very clean
# The purple! 😜
#
# Great Location
# Nothing I can think of
#
# Location and very friendly team, clean, nice service with a possibility of an early checkin and with providing 2 joint rooms🤗 Especially on hot days, refreshments in the lobby were very nice touch; super convenient for a trip to and from Gare de l’Est
# Inability to open the doors / issue with WiFi - but this is really kind of Force Majeure after the IT issues during that week
#
# Would be nice to have a possibility of less pricy option for breakfast for the children
#
# Comfort & location. The top floor views were amazing
#
# Location to train station.
# Superior double room on the 4th was small with limited room to move about.
#
# Location. Very accessible to trains for out of paris trips and metro for within paris trips. Good breakfast. A lot of restaurants around to eat even late night.
# Overall stay was ok except for the first night because the air conditioning wasn’t working on our suite. Had to transfer to another room which wasted our time during our vacation. New room was ok.
#
# The location was perfect
# I cannot say dislike, but it was a little bit too much of a room fragrance in the foyer
#
# near train station, metro station in front, easy to attend facilities,uncomplicated reception, questions answered satisfying
#
# Location next to metro to get into the city.
# Nice room with a cute balcony.
# Friendly staff
# The areas isn’t great to walk around especially in the evening but the metro is right outside so that was fine
#
# Opposite to gare de list train station and metro easy to transpot every where in paris by metro near the hotel many shops and markets
# They talk 137 $ as deposit while they didnt mention it in hotel polisies and as they say they give back but i didnt get it ill waite and see
#
# The tv-cable in the room didn't work for two nights and there was no one to fix it.
#
# I liked the room and it was comfortable and clean. The breakfast in the morning was amazing!! The Staff were kind and very helpful!
# I thought the price of the room included the tourist tax but I ended having to pay additional. The location was close to a train station but if you’re heading out, it’s not the main train station.
#
# Located close to the Gare de l'Est, this is convenient for those traveling be train.
# Gare du Nord is a 5-minute walk away, which is convenient if you need to visit the exhibition center or Charles de Gaulle Airport.
# Lovely breakfast.
# Rooms need renovation.
# Rooms and restrooms are tiny.
# Based on this, I think that the accommodation prices are a bit overpriced.
# The district itself is not a tourist one, not so calm and beautiful.
#
# Modern hotel, excellent location opposite Gare De Est. Comfortable and modern room with balcony.
# Aircon was poor and the evening was warm. We booked balcony room so made a plan, but aircon should be checked before arrival.
#
# Location
# Rugs were stained and dirty
#
# Staffs are patient and nice
# bottle of water in the room should be provided everyday
#
# Very conveniently located just across Gare de l'Est (East train station), which is just one metro stop and even in reasonable walking distance from Gare du North (North train station). Much more reasonably priced than alternatives across and around Gare du Nord. 4-star service. Although just across the train station I felt very safe, also because of a security guard at the hotel entrance and a reception area, which is always manned by 2 or more people; also no rooms at reception level. Clean facility (public rooms and room) and friendly staff. Very comfortable bed and very quiet room. Breakfast was typically "French", but for international travellers there were also savoury alternatives. Metro stop with short connections to all of Paris just at the entrance of the hotel.
# Room was very (!) small; perfect for a solo business traveller not being pretentious -like me- but for couples this double room could be received as too small. Not the kind of room to stay for other reasons than only sleeping and having a shower. Some may miss a restaurant, but there are multiple lunch and dinner options in short walking distance; a great cocktail bar is just next door.
#
# Dear NH Paris and Booking.com Team,
#
# I hope this message finds you well. I am writing to bring to your attention an issue regarding the security deposit that was charged during my recent stay.
#
# Upon checking my credit card statement, I have noticed the following charges:
#
# 288.58 euro charged via Booking.com
# 82.52 euro charged at the hotel reception
# However, I have only received a bill for 32.52 euro. Upon inquiry with NH Paris, I was informed that the remaining 50 euro, held as a security deposit, would be refunded.
#
# I kindly request your assistance in verifying these charges and promptly returning the 50 euro security deposit to my account. For your convenience, I have attached a screenshot of the credit card transaction for your reference.
#
# Thank you for your attention to this matter. I look forward to your prompt response and the resolution of this issue.
#
# The room we had was fabulous - spacious and comfortable, with views of the Eiffel Tower and Sacre Coeur. Very accessible to Gare de l'Est for both metro and Eurail trains.
# We felt a little unsafe walking around the local area in the evenings. Best to stick to metro travel or Ubers at night rather than walking.
#
# When the trains are cancelled this is a good bolt hole for 1 night. Room bigger than average for Paris and not expensive
# nothing
#
# Location.
# No complaints.
#
# Great service, David was very welcoming and helpful so was Vincent too.
# Great location and comfortable.
# Very hot in the room.
#
# I like the quality services and the staffs are very friendly
# The bed size for 2 is too small
#
# It was near Gare d’est
#
# The location is excellent, and the value for money is good (the room is spacious and nice)
# We didn't have Internet for the fill 4 days. It's annoying because people go to this type of hotel on business travel or there can ve people without a plan and they are left without any means of communication. The staff is not very friendly.
#
# The location is perfect, just across the train station and the facilities are good.
#
# Good Location, close to Train Station (Gare du L’est), many restaurants surounding hotel
# The AirCon in my room not running well, a little bit Hot, I’d complaint but no respond, the day after still same “HOT”
#
# Location is great
# Rooms are small though
#
# No YouTube on TV.
# Please provide YOUTUBE on the Television. 😀
#
# Very clean hotel, beautiful rooms and good toiletries would certainly recommend this hotel
# The staff are rude as they dont understand English properly . The check in process was painful taking 1 hour for 11 people to check in. The hotel needs to give training to their staff on good customer service experience with a smile and being friendly . This was the only thing letting down such a lovely hotel
#
# great location
# nearby restaurants
# room heating system
#
# First room we had was tiny and gloomy, so asked for a street facing room instead. They obliged, was much brighter and nicer space
# Staff were friendly
# Location is AMAZING
# Wifi in the room kept disconnecting from all my devices, worked well in the 'business' lounge though. Weird they changed the pw in the middle of the night though.
# The smell they pump out in the welcome area is too overpowering /strong, would change that ASAP
#
# I HAVE LIKED THE HOTEL AND SPECIAL THANK TO ALL EMPLYEES ESPECIAL THOSE OF TEH RECEPTION, THEY ARE VERY HEPFULL AND POLIED
#
# The welcome we received was warm and the information given was clear. The reception area was clean and smart and had seating and drinks. The family suite room was spacious and clean with a lovely view of historic Gare de l'Est and the surrounding area. The location is great for travelling around Paris near both metro and mainline trains, and there are shops and restaurants alongside the hotel for convenience, plus a park nearby (although we didn't have time to check this out). The hotel also offered a free baggage hold service which was so helpful to us.
# The breakfast was quite expensive. It may be because we paid separately. The breakfast area also felt a little cramped but the food and service was lovely. However, with handy restaurants just outside, you could easily grab something there instead.
#
# For train travellers its location is really very good
# Nothing
#
# The staff was friendly and helped us make dinner reservations when needed.
#
# The hobos sleeping next to the entrance and urinating in front of every body
#
# Hotel is just outside metro station and it is very convenient to travel places from this location.Hotel was nice and clean.Complimentory juice for the customers.
#
# The bar, ability to get twin room at short notice
# Flirting a bit dirty
# Bugs in the room
#
# It was realy nice!
#
# Hotel staff was very friendly and helpful. The hotel’s location is convenient. The metro station and train station are all within walking distance.
# Our room is on the 4th floor but since it faces a busy street, it’s very noisy. If you are a light sleeper, you would not be able to have a good sleep.
#
# Breakfast was very good! Staff we’re excellent and a good selection!
# If I was being critical then the a good tidy up would improve the hotel
#
# Room/suite was very spacious. Electrical sockets placed conveniently next to each side of each bed!
#
# Location right next to Gare L’Est, and nearby Gare Du Nord, was ideal.
# Quite a lot of traffic noise.
#
# Location. Front desk staff was great and very friendly. Room was comfortable. Blackout curtains very good.
# Wifi was not working for a couple of days.
#
# Room was clean and tidy and location was excellent, right beside the metro & train station along with food options.
# Unfortunately, the WiFi was down when we arrived at the property and we were never informed. We had to go externally to look for WiFi. NB// unfortunately, this is a service issue with their broadband provider but it would have been nice to be informed by the hotel the broadband was down upon arrival. Expensive breakfast and mini bar option but this is Paris so should be expected. Select staff were extremely welcoming and so helpful, others cold and did the bare minimum.
#
# Close to the metro
# Carpets
#
# Spacious family room, useful location, clean and bright decor.
#
# Location - if traveling by train
# Price - decent
# Internet connection is bad - 2 out of the 3 nights our devices connected to the wifi but without any internet connection.
#
# Close to all tourists attractions. Good transport links
#
# The hotel is just in front of the Gare de l'Est and related metro station. It is a 20-minutes walking distance from city center (e.g. Beaubourg). The hotel was clean and quite, a good cost-benefit compromise. Recommendable.
# We didn't chose breakfast - very expensive. But next door it's plenty of good bistrots.
#
# It was clean. The bed was very comfortable.
# The room was very small. Not much space to move around or put your stuff. Couldn’t have children in there. A bit disappointed in that respect.
#
# The location was excellent, close proximity to the train station. Breakfast was good, staff was pleasant.
#
# The receptionist was very very polite and made our checking process very smooth.
#
# Hotel very neat and clean.
# N/A
#
# We were upgraded and had a suite with great views. Room was fresh and the bed very comfy!
# All good
#
# Good value for money. Clean hotel closed to Gare de L’Est. Recommended for a short stay in Paris
#
# Great suite for our family - separate sleeping areas for us and the kids. Lovely staff and sweets and treats in reception, which the kids loved. Great location for sightseeing, and an easy walk to Gare Du Nord. Perfect for what we needed.
# In the family suite, the second sleeping area doubles as a living area so there's not much space when the bed is unfolded. You had to clamber over the bed to get to the coffee machine, for example.
#
# Excellent location, excellent staff team have continued since handing over from Holiday Inn group to NH group. Staff had a room available for me even though I arrived in the morning.
# No wifi on arrival in room on that day.
#
# Room is was clean
# Nothing
#
# Location of the hotel
# Room of the hotel
# And staff
# My room access card was always deactivated and I need to go down and ask the staff to activate again
# I have suffered with with problem
#
# Also in the room there was very bad noise coming from ventilation fan same has been informed to hotel staff
#
# During checked in they said me we will return you security despite amont but they didn't send me back yet I request booking.com team to check with hotel and send my security deposit back.
#
# near train station and fast food restaurant
# no bidet when you go to toilet no water inside the toilet only toilet bowl how to wash?
#
# Room well appointed and comfortable. Excellent location. Staff friendly.
# Nothing.
#
# While this location is very practical for easy touring, this was the best hotel in this spot, also the locker service was great during the period between check-out and train trip schedule.
# The cleaners was too noisy at early morning chatting loudly and hitting the walls by their equipment, also check-in was a bit slow.
#
# Perfect location, quiet and friendly
# They have implemented a new IT system that slowed things down
#
# Superb Location, very friendly staff, and clean and updated rooms.
# Nothing
#
# Good location, in front of Gare de l'Est
# Staff very kind
#
# Location
# Noise
#
# Room was tidy and clean. Location was a little out of the way of the big attractions in walking distance but very central for public transportation so if you can get around that way, you'll be set.
# The shower was clean but had a bit of a hard time draining which was slightly inconvenient.
#
# Opposite Gare de L'est which makes getting around Paris really easy with the Metro. Rooms are quite small, but they are really clean and comfortable. Had the added bonus of a view of Sacre Coeur from our 7th floor room.
# Was able to get extra towels and products easily from cleaning staff and the front desk staff were always helpful. Breakfast was really good too with a wide range of hot and cold items.
# We tried a few bars around the hotel too and they were really good as well.
# Nothing to fault.
#
# The suite was huge and comfortable. It was a big surprise to see such spacious room in that part of Paris.
# The morning breakfast was always short of cutlery and eating space. Their plates are too small and many people ended up serving in multiple plates, leaving many guests serving themselves in paper napkins. But despite all these challenges, their staff were very polite and going extra mile to serve the guests at breakfast.
# The hotel should consider having adequate sized cutlery in adequate numbers. Also in holiday and peak season, they should have extended breakfast hours.
#
# Staff were very supportive and friendly, great location, very clean and spacious room
#
# The hotel was brilliantly located right across the road from the train station, allowing us easy access for our rail journey. The room was spacious with a very large bathroom. We had access to tea and coffee in our room and there was also an iron so we could freshen our clothes for the onward journey. The staff was helpful and efficient.
#
# The staff were fabulous, the beds were incredibly comfortable and the location was quiet. After a long flight from Australia this hotel was the most wonderful introduction to Paris we loved it.
#
# Atmosphere is great
#
# Everything was amazing
# Vincent was excellent with us
#
# The team were very helpful with some outside situations I encountered. They let me use the telephone for an important call until I got a replacement. The windows in the rooms can be open to let fresh air in. There are a lot of nice restaurants l and pâtisseries, bakeries and supermarket in walking distance. The bus stop and metro are practically right there when you exit the hotel and you minutes away from major points of interest.
# A bit of foot traffic from the train station can pass by at times past the front entrance of the hotel.
#
# Location
# The noise
#
# Amazing location, polite and attentive staff
# Nothing
#
# On entering the hotel it was really nice. It was smart, clean and staff ready to assist you. The room was exactly how it was on the page so we were really pleased with it. The shower was fantastic! The bed was clean and made tidy, and very comfortable. After reading some reviews that some customers were kept awake by the metro trains, that didn't really bother me as staying in the winter the door was shut anyway. You can barely hear them. So we did get a good night sleep. Bonus also being straight across ftom the train station. You can shop, eat, and hop onto all the metros to get you anywhere you needed to go, and it was very cheap. The local people were also very friendly and helpful with helping us with information. If you're travelling by eurostar like we did, the hotel is only a 10 minute walk away, and easy to find as down 1 long road. So overall it was a very pleasant stay. And we would stay again when we go back to Paris.
# Nothing at all
#
# Excellent staff, comfortable and clean room
# Nothing - all good
#
# clean and modern hotel, right across from station and at metro. staff was exceptional and spoke English well. they helped with directions and taxis. They even had a small bar in the hotel and water at front desk. beds were comfortable and rooms clean with coffee and tea in our 2 room suite. we felt the price for our room was reasonable for 3 people.
# only downfall was lights from train station were bright at night and worker noise at 5am wolk us up. we were told may not be safe at night but we felt good walking around the block and small park next door.
#
# Not applicable
#
# Bed was comfy, good location
# How small the room was, had damp marks on the ceiling also mold in the bathroom
#
# Clean, great staff very friendly
# I liked it nothing bad to say
#
# Location was great and room exceptional
#
# The view from the suite was insane !! I could see the Eiffel Tower, the church and train station, made our break !! Great location for travel we walked mostly around Paris bolts are cheap and right next to the tube Disney was a breeze to get too. Over all happy will return.
#
# Staff are rude...gave 2 bottles small water only for 2 days stay...I paid 7 euro for such a small watter for 2nd day ...don't stay at this hotel..lots of hidden charges.
#
# Localization
# Cost benefit
#
# Very friendly and welcoming staff, good location with discounted parking over the road. Property was clean and breakfast was nice. Really nice hotel with modern decor / design.
#
# Handy transportation with metro outside. Room small but clean & decent WiFi.
# The 25 euros per night pre paid for the mini bar.
#
# Beautiful room with a view of the Eiffel Tower, Gare de L'est station and Sacrè-Coeur..
# 3 nights of bliss, it's very busy place but couldn't hear any traffic, bed was very comfy and I had 2 towel swans with heart balloons, cupcakes and a keyring in my room for my birthday on arrival... staff are more than helpful too...
# N/A
#
# This place is fantastic in every respect. The location is ideal with metro access within feet of the entrance. It's in the heart of the 10e arrondissement which is not at all overwhelmed with tourists, but is an up and coming residential area with lots of shops, several vintage clothing stores, etc. The Gare de l'est is across the street, which a pretty interesting old train station with links to areas outside ile de france region. There is an excellent old-fashion restaurant just next door that is wonderful and inexpensive. The value for the price is almost unbelievable. I would definitely stay there again and recommend it to friends.
# I didn't like how it reminded me of the kind of terrible hotel room you can get in the US for more than twice the price, like at most chain hotels or a mom and pop motel. Our room was a little small by US standards, but we didn't mind at all.
#
# Good location.
# Mould in bathroom, small room, air con doesn’t work. Memory foam mattress was too hot.
#
# Location, cleanliness, comfortable.
# Nothing really.
#
# The 10 rating is essentially for the staff as much as anything else. Really amazing from the moment we arrived. They couldn't find our booking on the system at first, it took some time to locate and although there was some concern, they reassured us at reception they would find a room. All staff members from reception, lobby, breakfast and cleaners were exceptionally friendly and polite. Location is good next door to a popular Bouillon restaurant and close to convenience shops, kebabs and restaurants, while not quite in the city centre it feels perfect for us. We walked everywhere and this hotel was the ideal spot between Eiffel Tower, Notre Dam and Sacre couere areas.
#
# The breakfast was reasonable with the usual continental standard, breads, cooked meats, cheese, some fruit and pastries. Cooked option was limited to bacon, sausage and scrambled eggs but more than sufficient.
#
# Although the room was relatively small and slightly cluttered with furniture, the bed was comfortable and robes/slippers are provided on request. The juliet balcony was a nice touch allowing fresh air and nice view.
#
# This hotel is more functional than luxury but the price reflects this and we found it was extremely reasonable and perfect for our needs. I would definitely stay here again and recommend to anyone looking for a budget friendly hotel. Thank you to all the wonderful staff for making our stay extra special and memorable.
# The rooms could do with freshening up a bit and splash of paint, but otherwise I couldn't find any negatives.
#
# Check in Lady was slightly rude!
#
# The bed was comfortable and the location was very convenient for the train stations.
# I would expect more from a 4 star hotel, so only go here if it is comparable in price to 3 star hotel options. The room was very small and made smaller by inconvenient furniture which we had to move out of the way to get into bed.
#
# Good location.
# Nice room, clean, excellent service.
# Will stay there again.
#
# The room was too small, definitely not enough space if you are 2 people.
# It was not very clean as well .

# %% [markdown]
# While scraping, we have seen some reviews that are like this :

# %% [markdown]
# ![Ce client n'a pas laissé de commentaire](assets/problems/no_review.png)

# %% [markdown]
# Let's handle this

# %%
df4['all_reviews_text'] = df4['all_reviews_text'].str.replace(
    r"Ce client n'a pas laissé de commentaire", "", regex=True
)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               154 non-null    object
#  1   full_description  154 non-null    object
#  2   all_reviews_text  154 non-null    object
#  3   rating_subscores  154 non-null    object
# dtypes: object(4)
# memory usage: 10.1+ KB

# %% [markdown]
# Another problem that our reviews are in different languages, so to handle this we will translate them all in english

# %% [markdown]
# First solution

# %%
# !pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /opt/anaconda3/lib/python3.12/site-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
import re
from deep_translator import GoogleTranslator

# Function to split text into chunks of 5000 characters
def split_text(text, max_length=2000):
    """Split long text into chunks without breaking sentences."""
    sentences = re.split(r'(?<=[.!?]) +', text)  # Split by sentences
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        # Check if adding the next sentence exceeds the max_length
        if len(current_chunk) + len(sentence) <= max_length:
            current_chunk += sentence + " "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + " "
    
    # Add the last chunk
    if current_chunk:
        chunks.append(current_chunk.strip())
    
    return chunks

# Function to translate long text
def translate_long_text(text):
    """Translate long text by splitting it into smaller parts."""
    try:
        # Return original text if empty or NaN
        if pd.isnull(text) or text.strip() == "":
            return text
        
        # Split text into chunks of 5000 characters
        chunks = split_text(text)
        translated_chunks = []

        # Translate each chunk
        for chunk in chunks:
            translated_chunk = GoogleTranslator(source='auto', target='en').translate(chunk)
            translated_chunks.append(translated_chunk)
        
        # Combine translated chunks
        return " ".join(translated_chunks)

    except Exception as e:
        print(f"Error translating: {text[:50]}... -> {e}")
        return text

# %%
# Apply translation to the 'all_reviews_text' column and create a new column
df4['translated_reviews'] = df4['all_reviews_text'].apply(translate_long_text)

# %%
# Display sample data
print(df4[['all_reviews_text', 'translated_reviews']].head())
# Out:
#                                     all_reviews_text  \
# 0  J’aime bien cette établissement par ce que ils...
# 1  Toujours la gentillesse dans l accueil!\nLa mo...
# 2  Un personnel accueillant,reactif,tres poli.Mem...
# 3  La prise en charge du personnel, la situation ...
# 4  Personnelle vraiment sympathique et petit déje...
#
#                                   translated_reviews
# 0  I like this establishment because they are ver...
# 1  Always kind in the welcome!\nThe carpet on the...
# 2  Welcoming, responsive, very polite staff. Even...
# 3  The staff support, the unbeatable location in ...
# 4  Really friendly staff and very well done break...

# %%
df4[
    (df4['all_reviews_text'].str.strip() == "") |    # Empty strings
    (df4['all_reviews_text'].isnull())               # NaN values
]
# Out:
# Empty DataFrame
# Columns: [url, full_description, all_reviews_text, rating_subscores, translated_reviews]
# Index: []

# %%
df4[
    (df4['translated_reviews'].str.strip() == "") |    # Empty strings
    (df4['translated_reviews'].isnull())               # NaN values
]
# Out:
# Empty DataFrame
# Columns: [url, full_description, all_reviews_text, rating_subscores, translated_reviews]
# Index: []

# %%
df4.to_csv('translated_reviews_final.csv', index=False)

# %%
merged_df.head()
# Out:
#                               Name  Rating RatingText  \
# 0           NH Paris Gare de l'Est     8.1  Très bien
# 1       Citadines Austerlitz Paris     8.2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas     7.8       Bien
# 3  Best Western Hotel Opéra Drouot     8.0  Très bien
# 4                 Hotel de la Tour     8.2  Très bien
#
#                                            HotelLink  \
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...
#
#                                              address        lat       lng
# 0  5 rue du 8 Mai 1945, 10e arr., 75010 Paris, Fr...  48.875950  2.358766
# 1     27 Rue Esquirol, 13e arr., 75013 Paris, France  48.834906  2.360376
# 2  23 Avenue René Fonck, 19e arr., 75019 Paris, F...  48.880018  2.408066
# 3  4 Rue De La Grange Bateliere, 9e arr., 75009 P...  48.873089  2.342492
# 4  19 boulevard Edgar Quinet, 14e arr., 75014 Par...  48.841197  2.323891

# %%
final_dataset = pd.merge(merged_df, df4, left_on='HotelLink', right_on='url', how='inner')

# %%
final_dataset.drop(columns=['url'], inplace=True)

# %%
final_dataset.head()
# Out:
#                               Name  Rating RatingText  \
# 0           NH Paris Gare de l'Est     8.1  Très bien
# 1       Citadines Austerlitz Paris     8.2  Très bien
# 2  B&B HOTEL Paris Porte des Lilas     7.8       Bien
# 3  Best Western Hotel Opéra Drouot     8.0  Très bien
# 4                 Hotel de la Tour     8.2  Très bien
#
#                                            HotelLink  \
# 0  https://www.booking.com/hotel/fr/mercure-termi...
# 1  https://www.booking.com/hotel/fr/citadines-apa...
# 2  https://www.booking.com/hotel/fr/b-amp-b-porte...
# 3  https://www.booking.com/hotel/fr/comfort-opera...
# 4  https://www.booking.com/hotel/fr/de-la-tour-pa...
#
#                                              address        lat       lng  \
# 0  5 rue du 8 Mai 1945, 10e arr., 75010 Paris, Fr...  48.875950  2.358766
# 1     27 Rue Esquirol, 13e arr., 75013 Paris, France  48.834906  2.360376
# 2  23 Avenue René Fonck, 19e arr., 75019 Paris, F...  48.880018  2.408066
# 3  4 Rue De La Grange Bateliere, 9e arr., 75009 P...  48.873089  2.342492
# 4  19 boulevard Edgar Quinet, 14e arr., 75014 Par...  48.841197  2.323891
#
#                                     full_description  \
# 0  Le NH Paris Gare de l'Est est situé en face de...
# 1  Situé à mi-chemin entre le Quartier latin et l...
# 2  Situé dans le 19ème arrondissement de Paris, l...
# 3  Situé dans le quartier chic et central du 9ème...
# 4  Situé dans le 14ème arrondissement de Paris, l...
#
#                                     all_reviews_text  \
# 0  J’aime bien cette établissement par ce que ils...
# 1  Toujours la gentillesse dans l accueil!\nLa mo...
# 2  Un personnel accueillant,reactif,tres poli.Mem...
# 3  La prise en charge du personnel, la situation ...
# 4  Personnelle vraiment sympathique et petit déje...
#
#                                     rating_subscores  \
# 0  {'Personnel': 8.7, 'Équipements': 8.1, 'Propre...
# 1  {'Personnel': 9.2, 'Équipements': 8.1, 'Propre...
# 2  {'Personnel': 8.5, 'Équipements': 7.7, 'Propre...
# 3  {'Personnel': 9.0, 'Équipements': 7.9, 'Propre...
# 4  {'Personnel': 9.3, 'Équipements': 7.9, 'Propre...
#
#                                   translated_reviews
# 0  I like this establishment because they are ver...
# 1  Always kind in the welcome!\nThe carpet on the...
# 2  Welcoming, responsive, very polite staff. Even...
# 3  The staff support, the unbeatable location in ...
# 4  Really friendly staff and very well done break...

# %%
final_dataset.to_csv('final_dataset.csv', index=False)
